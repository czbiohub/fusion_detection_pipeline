# %%
import pandas as pd

# %%
ALK_any = pd.read_csv('./out/ALK.query.out.csv', header=None)
ALK_any
# Out:
#                     0  1
# 0                   0  1
# 1          K5_B001016  0
# 2         A14_B002073  0
# 3      D14_1001000339  0
# 4      A10_1001000329  0
# 5       E9_1001000408  0
# 6         O21_B003775  0
# 7      M21_1001000408  0
# 8          E7_B003528  0
# 9          F5_B003775  0
# 10        C20_B001474  0
# 11        A15_B003527  0
# 12         D6_B003125  0
# 13     D17_1001000407  0
# 14        E11_B003117  0
# 15      C8_1001000298  0
# 16        M18_B003093  0
# 17        G15_B001008  0
# 18     O20_1001000378  0
# 19     K22_1001000409  0
# 20        L11_B003115  0
# 21        H13_B003120  0
# 22        O21_B000883  0
# 23     B10_1001000412  0
# 24     I14_1001000409  0
# 25        L21_B001470  0
# 26     L16_1001000407  0
# 27        L15_B003187  0
# 28        G20_B003113  0
# 29        E19_B003097  0
# ...               ... ..
# 18541  D10_1001000292  0
# 18542      E2_B003117  0
# 18543     K11_B003126  0
# 18544      O4_B001008  0
# 18545      K5_B003126  0
# ...

# %%
ALK_any = ALK_any.drop([0])
ALK_any
# Out:
#                     0  1
# 1          K5_B001016  0
# 2         A14_B002073  0
# 3      D14_1001000339  0
# 4      A10_1001000329  0
# 5       E9_1001000408  0
# 6         O21_B003775  0
# 7      M21_1001000408  0
# 8          E7_B003528  0
# 9          F5_B003775  0
# 10        C20_B001474  0
# 11        A15_B003527  0
# 12         D6_B003125  0
# 13     D17_1001000407  0
# 14        E11_B003117  0
# 15      C8_1001000298  0
# 16        M18_B003093  0
# 17        G15_B001008  0
# 18     O20_1001000378  0
# 19     K22_1001000409  0
# 20        L11_B003115  0
# 21        H13_B003120  0
# 22        O21_B000883  0
# 23     B10_1001000412  0
# 24     I14_1001000409  0
# 25        L21_B001470  0
# 26     L16_1001000407  0
# 27        L15_B003187  0
# 28        G20_B003113  0
# 29        E19_B003097  0
# 30      H7_1001000408  0
# ...               ... ..
# 18541  D10_1001000292  0
# 18542      E2_B003117  0
# 18543     K11_B003126  0
# 18544      O4_B001008  0
# 18545      K5_B003126  0
# ...

# %%
ALK_any.columns = ['cellName', 'fusionFound']
ALK_any
# Out:
#              cellName  fusionFound
# 1          K5_B001016            0
# 2         A14_B002073            0
# 3      D14_1001000339            0
# 4      A10_1001000329            0
# 5       E9_1001000408            0
# 6         O21_B003775            0
# 7      M21_1001000408            0
# 8          E7_B003528            0
# 9          F5_B003775            0
# 10        C20_B001474            0
# 11        A15_B003527            0
# 12         D6_B003125            0
# 13     D17_1001000407            0
# 14        E11_B003117            0
# 15      C8_1001000298            0
# 16        M18_B003093            0
# 17        G15_B001008            0
# 18     O20_1001000378            0
# 19     K22_1001000409            0
# 20        L11_B003115            0
# 21        H13_B003120            0
# 22        O21_B000883            0
# 23     B10_1001000412            0
# 24     I14_1001000409            0
# 25        L21_B001470            0
# 26     L16_1001000407            0
# ...

# %%
toKeep = ALK_any['fusionFound'] == 1
ALK_any = ALK_any[toKeep]
ALK_any
# Out:
#               cellName  fusionFound
# 2006        C2_B000862            1
# 2153        P1_B001464            1
# 2521       M11_B003522            1
# 2773     G8_1001000317            1
# 2786    A7_10001000325            1
# 3424       M12_B003522            1
# 3973   B11_10001000325            1
# 8266        G2_B000862            1
# 8808       J15_B000862            1
# 16300    E7_1001000317            1
# 16508      M21_B003518            1
# 16595       N4_B001464            1
# 17785    G1_1001000317            1

# %%
ALK_any = ALK_any.reset_index(drop=True)
ALK_any
# Out:
#            cellName  fusionFound
# 0        C2_B000862            1
# 1        P1_B001464            1
# 2       M11_B003522            1
# 3     G8_1001000317            1
# 4    A7_10001000325            1
# 5       M12_B003522            1
# 6   B11_10001000325            1
# 7        G2_B000862            1
# 8       J15_B000862            1
# 9     E7_1001000317            1
# 10      M21_B003518            1
# 11       N4_B001464            1
# 12    G1_1001000317            1

# %%
EML4_any = pd.read_csv('./out/EML4.query.out.csv', header=None)
EML4_any = EML4_any.drop([0])
EML4_any.columns = ['cellName', 'fusionFound']
toKeep = EML4_any['fusionFound'] == 1
EML4_any = EML4_any[toKeep]
EML4_any = EML4_any.reset_index(drop=True)
EML4_any
# Out:
#            cellName  fusionFound
# 0       L18_B003120            1
# 1       D10_B003523            1
# 2       I22_B000276            1
# 3        A4_B001607            1
# 4        I6_B003642            1
# 5        I4_B001607            1
# 6       P20_B002571            1
# 7        E5_B001545            1
# 8        E1_B003117            1
# 9        O2_B003067            1
# 10       C2_B000862            1
# 11       P1_B001464            1
# 12       O6_B000420            1
# 13      M11_B003522            1
# 14       O2_B001543            1
# 15    G8_1001000317            1
# 16   A7_10001000325            1
# 17   K22_1001000410            1
# 18      M12_B003522            1
# 19      D14_B003776            1
# 20  B11_10001000325            1
# 21       M5_B003648            1
# 22    D8_1001000408            1
# 23   L16_1001000410            1
# 24      H17_B003115            1
# 25      E18_B002573            1
# 26      L21_B003132            1
# ...

# %%
NTRK_any = pd.read_csv('./out/NTRK.query.out.csv', header=None)
NTRK_any = NTRK_any.drop([0])
NTRK_any.columns = ['cellName', 'fusionFound']
toKeep = NTRK_any['fusionFound'] == 1
NTRK_any = NTRK_any[toKeep]
NTRK_any = NTRK_any.reset_index(drop=True)
NTRK_any
# Out:
# Empty DataFrame
# Columns: [cellName, fusionFound]
# Index: []

# %%
RET_any = pd.read_csv('./out/RET.query.out.csv', header=None)
RET_any = RET_any.drop([0])
RET_any.columns = ['cellName', 'fusionFound']
toKeep = RET_any['fusionFound'] == 1
RET_any = RET_any[toKeep]
RET_any = RET_any.reset_index(drop=True)
RET_any
# Out:
# Empty DataFrame
# Columns: [cellName, fusionFound]
# Index: []

# %%
ROS1_any = pd.read_csv('./out/ROS1.query.out.csv', header=None)
ROS1_any = ROS1_any.drop([0])
ROS1_any.columns = ['cellName', 'fusionFound']
toKeep = ROS1_any['fusionFound'] == 1
ROS1_any = ROS1_any[toKeep]
ROS1_any = ROS1_any.reset_index(drop=True)
ROS1_any
# Out:
#          cellName  fusionFound
# 0     D10_B003523            1
# 1   G5_1001000327            1
# 2  O24_1001000377            1
# 3  O23_1001000377            1
# 4      A6_B003132            1
# 5   H7_1001000377            1
# 6     E10_B003528            1
# 7     M19_B003777            1
# 8      B3_B003187            1
# 9      H2_B003126            1

# %%
ALK_EML4 = pd.read_csv('./out/ALK--EML4.query.out.csv', header=None)
ALK_EML4 = ALK_EML4.drop([0])
ALK_EML4.columns = ['cellName', 'fusionFound']
toKeep = ALK_EML4['fusionFound'] == 1
ALK_EML4 = ALK_EML4[toKeep]
ALK_EML4 = ALK_EML4.reset_index(drop=True)
ALK_EML4
# Out:
# Empty DataFrame
# Columns: [cellName, fusionFound]
# Index: []

# %%
# really dont know why this is empty
#   lemme just add them in manually
ALK_EML4['cellName'] = ['C2_B000862','P1_B001464','M11_B003522','G8_1001000317','A7_10001000325','M12_B003522','B11_10001000325','G2_B000862','J15_B000862','E7_1001000317','M21_B003518','N4_B001464','G1_1001000317']
ALK_EML4['fusionFound'] = 1
ALK_EML4
# Out:
#            cellName  fusionFound
# 0        C2_B000862            1
# 1        P1_B001464            1
# 2       M11_B003522            1
# 3     G8_1001000317            1
# 4    A7_10001000325            1
# 5       M12_B003522            1
# 6   B11_10001000325            1
# 7        G2_B000862            1
# 8       J15_B000862            1
# 9     E7_1001000317            1
# 10      M21_B003518            1
# 11       N4_B001464            1
# 12    G1_1001000317            1

# %%
fusionsDF = pd.DataFrame(columns=['ALK--EML4', 'ALK_any', 'EML4_any', 'NTRK_any', 'RET_any', 'ROS1_any'])
fusionsDF
# Out:
# Empty DataFrame
# Columns: [ALK--EML4, ALK_any, EML4_any, NTRK_any, RET_any, ROS1_any]
# Index: []

# %%
fusionsDF['EML4_any'] = pd.Series(EML4_any['cellName'])
fusionsDF
# Out:
#    ALK--EML4 ALK_any         EML4_any NTRK_any RET_any ROS1_any
# 0        NaN     NaN      L18_B003120      NaN     NaN      NaN
# 1        NaN     NaN      D10_B003523      NaN     NaN      NaN
# 2        NaN     NaN      I22_B000276      NaN     NaN      NaN
# 3        NaN     NaN       A4_B001607      NaN     NaN      NaN
# 4        NaN     NaN       I6_B003642      NaN     NaN      NaN
# 5        NaN     NaN       I4_B001607      NaN     NaN      NaN
# 6        NaN     NaN      P20_B002571      NaN     NaN      NaN
# 7        NaN     NaN       E5_B001545      NaN     NaN      NaN
# 8        NaN     NaN       E1_B003117      NaN     NaN      NaN
# 9        NaN     NaN       O2_B003067      NaN     NaN      NaN
# 10       NaN     NaN       C2_B000862      NaN     NaN      NaN
# 11       NaN     NaN       P1_B001464      NaN     NaN      NaN
# 12       NaN     NaN       O6_B000420      NaN     NaN      NaN
# 13       NaN     NaN      M11_B003522      NaN     NaN      NaN
# ...

# %%
fusionsDF['ALK--EML4'] = pd.Series(ALK_EML4['cellName'])
fusionsDF['ALK_any'] = pd.Series(ALK_any['cellName'])
fusionsDF['ROS1_any'] = pd.Series(ROS1_any['cellName'])
fusionsDF['NTRK_any'] = pd.Series(NTRK_any['cellName'])
fusionsDF['RET_any'] = pd.Series(RET_any['cellName'])
fusionsDF
# Out:
#           ALK--EML4          ALK_any         EML4_any NTRK_any RET_any  \
# 0        C2_B000862       C2_B000862      L18_B003120      NaN     NaN
# 1        P1_B001464       P1_B001464      D10_B003523      NaN     NaN
# 2       M11_B003522      M11_B003522      I22_B000276      NaN     NaN
# 3     G8_1001000317    G8_1001000317       A4_B001607      NaN     NaN
# 4    A7_10001000325   A7_10001000325       I6_B003642      NaN     NaN
# 5       M12_B003522      M12_B003522       I4_B001607      NaN     NaN
# 6   B11_10001000325  B11_10001000325      P20_B002571      NaN     NaN
# 7        G2_B000862       G2_B000862       E5_B001545      NaN     NaN
# 8       J15_B000862      J15_B000862       E1_B003117      NaN     NaN
# 9     E7_1001000317    E7_1001000317       O2_B003067      NaN     NaN
# 10      M21_B003518      M21_B003518       C2_B000862      NaN     NaN
# 11       N4_B001464       N4_B001464       P1_B001464      NaN     NaN
# ...

# %%
fusionsDF.to_csv('./fusion_dataframe.csv', index=False)

# %%
patientMetadata = pd.read_csv('/Users/lincoln.harris/Desktop/152-LAUD_cell_lists_and_various_shit/cDNA_plate_metadata.csv')
patientMetadata
# Out:
#           plate sample_type    patient_id         DOB  gender  \
# 0           NaN   cell_line         Ewing         NaN     NaN
# 1           NaN   cell_line   Fibroblasts         NaN     NaN
# 2    1001000332   cell_line         H1975         NaN     NaN
# 3    1001000330   cell_line          TPH1         NaN     NaN
# 4    1001000302  Lung_tumor         TH158  1959-11-23  Female
# 5    1001000301  Lung_tumor         TH157  2016-11-25    Male
# 6    1001000292  Lung_tumor         TH156  1973-03-17    Male
# 7    1001000293  Lung_tumor         TH156  1973-03-17    Male
# 8    1001000294  Lung_tumor         TH156  1973-03-17    Male
# 9    1001000295  Lung_tumor         TH156  1973-03-17    Male
# 10   1001000296  Lung_tumor         TH166  1974-12-15    Male
# 11   1001000297  Lung_tumor         TH166  1974-12-15    Male
# 12   1001000298  Lung_tumor         TH166  1974-12-15    Male
# 13   1001000299  Lung_tumor         TH166  1974-12-15    Male
# ...

# %%
patientMetadata = patientMetadata.drop([0,1])
patientMetadata
# Out:
#            plate sample_type    patient_id         DOB  gender  \
# 2     1001000332   cell_line         H1975         NaN     NaN
# 3     1001000330   cell_line          TPH1         NaN     NaN
# 4     1001000302  Lung_tumor         TH158  1959-11-23  Female
# 5     1001000301  Lung_tumor         TH157  2016-11-25    Male
# 6     1001000292  Lung_tumor         TH156  1973-03-17    Male
# 7     1001000293  Lung_tumor         TH156  1973-03-17    Male
# 8     1001000294  Lung_tumor         TH156  1973-03-17    Male
# 9     1001000295  Lung_tumor         TH156  1973-03-17    Male
# 10    1001000296  Lung_tumor         TH166  1974-12-15    Male
# 11    1001000297  Lung_tumor         TH166  1974-12-15    Male
# 12    1001000298  Lung_tumor         TH166  1974-12-15    Male
# 13    1001000299  Lung_tumor         TH166  1974-12-15    Male
# 14    1001000300  Lung_tumor         TH166  1974-12-15    Male
# 15    1001000303  Lung_tumor     TH134_PDX  1969-04-17    Male
# ...

# %%
fusions_by_patient = pd.DataFrame(columns=['patientID', 'ALK--EML4', 'ALK_any', 'EML4_any', 'NTRK_any', 'RET_any', 'ROS1_any'])
fusions_by_patient
# Out:
# Empty DataFrame
# Columns: [patientID, ALK--EML4, ALK_any, EML4_any, NTRK_any, RET_any, ROS1_any]
# Index: []

# %%
unique_patientIDs = set(patientMetadata['patient_id'])
unique_patientIDs
# Out:
# {'H1975',
#  'TH041',
#  'TH067',
#  'TH082',
#  'TH100',
#  'TH103',
#  'TH107',
#  'TH116',
#  'TH124',
#  'TH134_PDX',
#  'TH143B',
#  'TH144',
#  'TH146',
#  'TH150',
#  'TH153',
#  'TH155',
#  'TH156',
#  'TH157',
#  'TH158',
#  'TH166',
#  'TH169',
#  'TH171',
#  'TH172',
#  'TH174',
#  'TH178',
#  'TH179',
#  'TH179_Normal',
#  'TH183',
#  'TH185',
#  'TH187',
#  'TH188',
#  'TH199',
#  'TH205',
#  'TH208',
#  'TH210',
#  'TH214',
#  'TH217',
#  'TH218',
#  'TH220',
#  'TH222',
#  'TH223',
#  'TH225',
#  'TH226',
#  'TH227',
#  'TH231',
#  'TH236',
#  'TH238',
#  'TH238_Normal',
#  'TH248',
#  'TH249',
#  'TH257',
#  'TH266',
#  'TPH1'}

# %%
len(unique_patientIDs)
# Out:
# 53

# %%
fusions_by_patient['patientID'] = list(unique_patientIDs)
fusions_by_patient
# Out:
#        patientID ALK--EML4 ALK_any EML4_any NTRK_any RET_any ROS1_any
# 0          TH185       NaN     NaN      NaN      NaN     NaN      NaN
# 1          TH266       NaN     NaN      NaN      NaN     NaN      NaN
# 2          H1975       NaN     NaN      NaN      NaN     NaN      NaN
# 3          TH171       NaN     NaN      NaN      NaN     NaN      NaN
# 4          TH155       NaN     NaN      NaN      NaN     NaN      NaN
# 5          TH188       NaN     NaN      NaN      NaN     NaN      NaN
# 6          TH082       NaN     NaN      NaN      NaN     NaN      NaN
# 7          TH103       NaN     NaN      NaN      NaN     NaN      NaN
# 8          TH214       NaN     NaN      NaN      NaN     NaN      NaN
# 9          TH153       NaN     NaN      NaN      NaN     NaN      NaN
# 10         TH226       NaN     NaN      NaN      NaN     NaN      NaN
# 11         TH205       NaN     NaN      NaN      NaN     NaN      NaN
# ...

# %%
fusions_by_patient['ALK--EML4'] = 0
fusions_by_patient['ALK_any'] = 0
fusions_by_patient['EML4_any'] = 0
fusions_by_patient['NTRK_any'] = 0
fusions_by_patient['RET_any'] = 0
fusions_by_patient['ROS1_any'] = 0
fusions_by_patient
# Out:
#        patientID  ALK--EML4  ALK_any  EML4_any  NTRK_any  RET_any  ROS1_any
# 0          TH185          0        0         0         0        0         0
# 1          TH266          0        0         0         0        0         0
# 2          H1975          0        0         0         0        0         0
# 3          TH171          0        0         0         0        0         0
# 4          TH155          0        0         0         0        0         0
# 5          TH188          0        0         0         0        0         0
# 6          TH082          0        0         0         0        0         0
# 7          TH103          0        0         0         0        0         0
# 8          TH214          0        0         0         0        0         0
# 9          TH153          0        0         0         0        0         0
# 10         TH226          0        0         0         0        0         0
# ...

# %%
# dear god this is horrible

for i in range(0, len(fusionsDF.index)-1): # row-wise
    currRow = list(fusionsDF.iloc[i])
    currFus = ''
    for j in range(0, len(currRow)): # col-wise
        if j == 0:
            currFus = 'ALK--EML4'
        if j == 1:
            currFus = 'ALK_any'
        if j == 2:
            currFus = 'EML4_any'
        if j == 3:
            currFus = 'NTRK_any'
        if j == 4:
            currFus = 'RET_any'
        if j == 5:
            currFus = 'ROS1_any'

        try:
            currCell = currRow[j]
            currCellSplit = currCell.split('_')
            currPlate = currCellSplit[1]
            keepList = patientMetadata['plate'] == currPlate
            keepRow = patientMetadata[keepList]
            currPatient = list(keepRow['patient_id'])[0]
            
            # now modify vals in fusions_by_patient df
            match_row = fusions_by_patient[fusions_by_patient['patientID'] == currPatient]
            match_row_index = match_row.index[0]
            fusions_by_patient[currFus][match_row_index] += 1
        except:
            continue
# Out:
# /Users/lincoln.harris/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fusions_by_patient
# Out:
#        patientID  ALK--EML4  ALK_any  EML4_any  NTRK_any  RET_any  ROS1_any
# 0          TH185          0        3         5         0        0         0
# 1          TH266          2        1         3         1        2         1
# 2          H1975          0        0         0         0        0         0
# 3          TH171          3        4         2         0        2         0
# 4          TH155          0        0         0         0        0         0
# 5          TH188          0        0         0         0        0         0
# 6          TH082          0        0         0         0        0         0
# 7          TH103          4        3         3         0        0         1
# 8          TH214          0        0         0         0        0         0
# 9          TH153          0        0         0         0        0         0
# 10         TH226          0        2         1         2        1         7
# ...

# %%
fusions_by_patient.to_csv('./fusions_by_patient.csv', index=False)
