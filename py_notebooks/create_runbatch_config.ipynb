# %%
# script: create_runbatch_config
# authors: Olga Botvinnik & Lincoln Harris
# date: 10.11.18
#
# Trying to build the input file to give tracer_pipeline.rf (required for batch mode run)

# %%
# get all of the run prefixes w/in immuneCells_9.27
bucketPrefixes = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/'
f = 'nonImmune_bams_9.27_prefixes.txt'
! aws s3 ls $bucketPrefixes > $f
! cat $f
# Out:
#                            PRE 170125/
#                            PRE 170129/
#                            PRE 170202/
#                            PRE 170215/
#                            PRE 170504/
#                            PRE 170508/
#                            PRE 170510/
#                            PRE 171120/
#                            PRE 180226/
#                            PRE 180307/
#                            PRE 180319/
#                            PRE 180320/
#                            PRE 180405/
#                            PRE 180423/
#                            PRE 180516/
#                            PRE 180519/
#                            PRE 180601/
#                            PRE 180604/
#                            PRE 180711/
#                            PRE 180831/
#                            PRE 180911/
# 2018-09-27 12:03:37          0

# %%
# read run names into a dataframe
#     with pandas!!
import pandas as pd
pd.options.display.max_colwidth = 500 # module config? 

runs_df = pd.read_table(f, delim_whitespace=True, header=None, names=['is_prefix', 'run_name'])
runs_df
# Out:
#      is_prefix  run_name
# 0          PRE   170125/
# 1          PRE   170129/
# 2          PRE   170202/
# 3          PRE   170215/
# 4          PRE   170504/
# 5          PRE   170508/
# 6          PRE   170510/
# 7          PRE   171120/
# 8          PRE   180226/
# 9          PRE   180307/
# 10         PRE   180319/
# 11         PRE   180320/
# 12         PRE   180405/
# 13         PRE   180423/
# 14         PRE   180516/
# 15         PRE   180519/
# 16         PRE   180601/
# 17         PRE   180604/
# 18         PRE   180711/
# 19         PRE   180831/
# 20         PRE   180911/
# 21  2018-09-27  12:03:37

# %%
# can i add a full_path col? 
runs_df['full_path'] = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/' + runs_df['run_name']
runs_df
# Out:
#      is_prefix  run_name  \
# 0          PRE   170125/
# 1          PRE   170129/
# 2          PRE   170202/
# 3          PRE   170215/
# 4          PRE   170504/
# 5          PRE   170508/
# 6          PRE   170510/
# 7          PRE   171120/
# 8          PRE   180226/
# 9          PRE   180307/
# 10         PRE   180319/
# 11         PRE   180320/
# 12         PRE   180405/
# 13         PRE   180423/
# 14         PRE   180516/
# 15         PRE   180519/
# 16         PRE   180601/
# 17         PRE   180604/
# 18         PRE   180711/
# 19         PRE   180831/
# 20         PRE   180911/
# 21  2018-09-27  12:03:37
#
#                                                              full_path
# 0    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170125/
# 1    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170129/
# 2    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170202/
# 3    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170215/
# 4    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170504/
# 5    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170508/
# 6    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170510/
# 7    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/171120/
# 8    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/
# 9    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180307/
# 10   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180319/
# 11   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180320/
# 12   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180405/
# 13   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180423/
# 14   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180516/
# 15   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180519/
# 16   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180601/
# 17   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180604/
# 18   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180711/
# 19   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180831/
# 20   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180911/
# 21  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/12:03:37

# %%
# get all of the cells in a given run directory
prefix = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/'
txt = 'runX_cells.txt'
! aws s3 ls $prefix > $txt
! cat $txt
# Out:
#                            PRE A1_B001800/
#                            PRE A21_1001000366/
#                            PRE A21_B003049/
#                            PRE A2_B001797/
#                            PRE A2_B001798/
#                            PRE A2_B001799/
#                            PRE A2_B003785/
#                            PRE A3_B001798/
#                            PRE A4_1001000362/
#                            PRE A4_B001798/
#                            PRE A4_B003785/
#                            PRE A5_1001000365/
#                            PRE A5_B001798/
#                            PRE A5_B001799/
#                            PRE A5_B001800/
#                            PRE A6_1001000377/
#                            PRE B21_B003049/
#                            PRE B2_B001797/
#                            PRE B2_B001798/
#                            PRE B2_B001799/
#                            PRE B3_B001797/
#                            PRE B3_B001798/
#                            PRE B3_B001799/
#                            PRE B3_B003785/
#                            PRE B4_B001797/
#                            PRE B5_1001000362/
#                            PRE B5_B001797/
#                            PRE B5_B001799/
#                            PRE B5_B003785/
#                            PRE B6_1001000377/
#                            PRE C16_1001000377/
#                            PRE C1_B001798/
#                            PRE C2_B001798/
#                            PRE C2_B001799/
#                            PRE C3_1001000362/
#                            PRE C3_B001799/
#                            PRE C3_B003785/
#                            PRE C4_B001798/
#                            PRE C5_B001797/
#                            PRE C5_B001798/
#                            PRE C5_B001799/
#                            PRE C5_B001800/
#                            PRE D15_1001000365/
#                            PRE D19_1001000365/
#                            PRE D1_B001797/
#                            PRE D1_B001798/
#                            PRE D2_B001799/
#                            PRE D3_B001799/
#                            PRE D4_B001797/
#                            PRE E1_1001000366/
#                            PRE E1_B001797/
#                            PRE E1_B001798/
#                            PRE E1_B001800/
#                            PRE E3_B001798/
#                            PRE E3_B001799/
#                            PRE E3_B001800/
#                            PRE E4_1001000366/
#                            PRE E4_B003785/
#                            PRE E5_B001797/
#                            PRE E5_B001799/
#                            PRE F1_B001797/
#                            PRE F1_B001799/
#                            PRE F1_B001800/
#                            PRE F2_B001798/
#                            PRE F3_B001798/
#                            PRE F4_1001000362/
#                            PRE F5_B001799/
#                            PRE F5_B001800/
#                            PRE G17_1001000365/
#                            PRE G1_1001000413/
#                            PRE G1_B001797/
#                            PRE G1_B001799/
#                            PRE G1_B001800/
#                            PRE G1_B003785/
#                            PRE G2_1001000365/
#                            PRE G2_B003785/
#                            PRE G3_B001797/
#                            PRE G3_B001799/
#                            PRE G3_B003785/
#                            PRE G4_B001797/
#                            PRE G4_B001799/
#                            PRE G5_B001797/
#                            PRE G5_B001798/
#                            PRE G5_B001799/
#                            PRE G5_B003785/
#                            PRE H12_1001000365/
#                            PRE H19_1001000363/
#                            PRE H1_B001797/
#                            PRE H1_B001799/
#                            PRE H1_B003785/
#                            PRE H21_B003049/
#                            PRE H2_B001798/
#                            PRE H2_B001799/
#                            PRE H3_1001000413/
#                            PRE H3_B003785/
#                            PRE H4_B001800/
#                            PRE I18_1001000365/
#                            PRE I1_B001797/
#                            PRE I1_B001798/
#                            PRE I2_B001797/
#                            PRE I2_B001799/
#                            PRE I2_B003785/
#                            PRE I3_B001797/
#                            PRE I3_B001799/
#                            PRE I4_B001797/
#                            PRE I4_B001800/
#                            PRE I5_B001797/
#                            PRE I5_B001799/
#                            PRE I5_B003785/
#                            PRE J11_1001000365/
#                            PRE J19_1001000377/
#                            PRE J1_B001797/
#                            PRE J1_B001798/
#                            PRE J2_B001797/
#                            PRE J2_B001800/
#                            PRE J2_B003785/
#                            PRE J3_B001797/
#                            PRE J3_B001798/
#                            PRE J3_B001799/
#                            PRE J3_B001800/
#                            PRE J4_B001799/
#                            PRE J5_B001797/
#                            PRE J5_B001798/
#                            PRE K16_1001000377/
#                            PRE K1_1001000362/
#                            PRE K1_B001797/
#                            PRE K1_B001799/
#                            PRE K1_B001800/
#                            PRE K2_B001797/
#                            PRE K2_B001798/
#                            PRE K2_B001800/
#                            PRE K3_B001797/
#                            PRE K3_B001798/
#                            PRE K3_B001799/
#                            PRE K4_B001797/
#                            PRE K4_B001800/
#                            PRE K5_B001797/
#                            PRE K5_B001798/
#                            PRE K5_B001799/
#                            PRE K5_B001800/
#                            PRE L1_B001797/
#                            PRE L1_B001798/
#                            PRE L1_B001799/
#                            PRE L1_B003785/
#                            PRE L2_1001000413/
#                            PRE L2_B001797/
#                            PRE L2_B001798/
#                            PRE L2_B001800/
#                            PRE L2_B003785/
#                            PRE L3_B001797/
#                            PRE L3_B001798/
#                            PRE L3_B001800/
#                            PRE L3_B003785/
#                            PRE L4_B001797/
#                            PRE L4_B001798/
#                            PRE L4_B001799/
#                            PRE L5_B001797/
#                            PRE L5_B001798/
#                            PRE M1_B001797/
#                            PRE M1_B001800/
#                            PRE M21_B003049/
#                            PRE M2_B001797/
#                            PRE M2_B001800/
#                            PRE M3_B001797/
#                            PRE M3_B001800/
#                            PRE M3_B003785/
#                            PRE M4_B001797/
#                            PRE M4_B001798/
#                            PRE M4_B001800/
#                            PRE M4_B003785/
#                            PRE M5_B001797/
#                            PRE N1_B001797/
#                            PRE N1_B001800/
#                            PRE N1_B003785/
#                            PRE N2_B001797/
#                            PRE N2_B001800/
#                            PRE N2_B003785/
#                            PRE N3_B001797/
#                            PRE N3_B001798/
#                            PRE N3_B001799/
#                            PRE N4_B001797/
#                            PRE N4_B001798/
#                            PRE N4_B001799/
#                            PRE N4_B001800/
#                            PRE N4_B003785/
#                            PRE N5_B001797/
#                            PRE N5_B003785/
#                            PRE O1_B001797/
#                            PRE O1_B001798/
#                            PRE O1_B001799/
#                            PRE O1_B001800/
#                            PRE O1_B003785/
#                            PRE O2_1001000413/
#                            PRE O2_B001797/
#                            PRE O2_B001798/
#                            PRE O2_B001799/
#                            PRE O2_B001800/
#                            PRE O2_B003785/
#                            PRE O3_B001797/
#                            PRE O3_B001800/
#                            PRE O4_B001797/
#                            PRE O4_B001800/
#                            PRE O4_B003785/
#                            PRE O5_B001797/
#                            PRE O5_B001798/
#                            PRE O5_B001799/
#                            PRE O5_B001800/
#                            PRE O5_B003785/
#                            PRE P1_1001000413/
#                            PRE P1_B001797/
#                            PRE P1_B001798/
#                            PRE P1_B001799/
#                            PRE P1_B001800/
#                            PRE P21_1001000366/
#                            PRE P2_B001797/
#                            PRE P2_B001798/
#                            PRE P2_B003785/
#                            PRE P3_B001797/
#                            PRE P3_B001800/
#                            PRE P3_B003785/
#                            PRE P4_B001797/
#                            PRE P4_B001800/
#                            PRE P4_B003785/
#                            PRE P5_B001797/
#                            PRE P5_B001798/
#                            PRE P5_B001799/
#                            PRE P5_B001800/
#                            PRE P5_B003785/

# %%
# read 180226 cell names into a dataframe
cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])
cells_df
# Out:
#     is_prefix        cell_name
# 0         PRE      A1_B001800/
# 1         PRE  A21_1001000366/
# 2         PRE     A21_B003049/
# 3         PRE      A2_B001797/
# 4         PRE      A2_B001798/
# 5         PRE      A2_B001799/
# 6         PRE      A2_B003785/
# 7         PRE      A3_B001798/
# 8         PRE   A4_1001000362/
# 9         PRE      A4_B001798/
# 10        PRE      A4_B003785/
# 11        PRE   A5_1001000365/
# 12        PRE      A5_B001798/
# 13        PRE      A5_B001799/
# 14        PRE      A5_B001800/
# 15        PRE   A6_1001000377/
# 16        PRE     B21_B003049/
# 17        PRE      B2_B001797/
# 18        PRE      B2_B001798/
# 19        PRE      B2_B001799/
# 20        PRE      B3_B001797/
# 21        PRE      B3_B001798/
# 22        PRE      B3_B001799/
# 23        PRE      B3_B003785/
# 24        PRE      B4_B001797/
# 25        PRE   B5_1001000362/
# 26        PRE      B5_B001797/
# 27        PRE      B5_B001799/
# 28        PRE      B5_B003785/
# 29        PRE   B6_1001000377/
# ..        ...              ...
# 198       PRE      O3_B001797/
# 199       PRE      O3_B001800/
# 200       PRE      O4_B001797/
# 201       PRE      O4_B001800/
# 202       PRE      O4_B003785/
# 203       PRE      O5_B001797/
# 204       PRE      O5_B001798/
# 205       PRE      O5_B001799/
# 206       PRE      O5_B001800/
# 207       PRE      O5_B003785/
# 208       PRE   P1_1001000413/
# 209       PRE      P1_B001797/
# 210       PRE      P1_B001798/
# 211       PRE      P1_B001799/
# 212       PRE      P1_B001800/
# 213       PRE  P21_1001000366/
# 214       PRE      P2_B001797/
# 215       PRE      P2_B001798/
# 216       PRE      P2_B003785/
# 217       PRE      P3_B001797/
# 218       PRE      P3_B001800/
# 219       PRE      P3_B003785/
# 220       PRE      P4_B001797/
# 221       PRE      P4_B001800/
# 222       PRE      P4_B003785/
# 223       PRE      P5_B001797/
# 224       PRE      P5_B001798/
# 225       PRE      P5_B001799/
# 226       PRE      P5_B001800/
# 227       PRE      P5_B003785/
#
# [228 rows x 2 columns]

# %%
# ls one of our s3 cell directories
test_files = ! aws s3 ls $prefix\P5_B001799/ # what does backslash do? 
test_files
# Out:
# []

# %%
# get full s3 paths for fastq file (R1), then add them to a new col in cells_df

def get_fastqs_R1(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    fq_line = [x for x in lines if x.endswith('R1_001.fastq.gz')][0] # get the fastq files, specifically
    fq_basename = fq_line.split()[-1]
    return f'{s3_location}{fq_basename}'


cells_df['input_fq_1'] = cells_df['cell_name'].map(get_fastqs_R1) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz

# %%
# get full s3 paths for fastq file (R2), then add them to a new col in cells_df

def get_fastqs_R2(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    try:
        fq_line = [x for x in lines if x.endswith('R2_001.fastq.gz')][0] # get the fastq files, specifically
        fq_basename = fq_line.split()[-1]
        #print(s3_location)
        return f'{s3_location}{fq_basename}'
    except IndexError:
        return

cells_df['input_fq_2'] = cells_df['cell_name'].map(get_fastqs_R2) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#         sample_id  \
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798
#
#                                                                                                            input_fq_2
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R2_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R2_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R2_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R2_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R2_001.fastq.gz

# %%
# add a sample_id col
cells_df['sample_id'] = cells_df.cell_name.str.strip('/') # getting rid of the forward slashes
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#         sample_id  \
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798
#
#                                                                                                            input_fq_2
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R2_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R2_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R2_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R2_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R2_001.fastq.gz

# %%
# building the output vcf string
import os

cells_df['output_prefix'] = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/'
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#         sample_id  \
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798
#
#                                                                                                            input_fq_2  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R2_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R2_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R2_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R2_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R2_001.fastq.gz
#
#                                                             output_prefix
# 0  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 2  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 3  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 4  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/

# %%
# subset cells_df by only what we want
cols_to_keep = ['sample_id', 'input_fq_1', 'input_fq_1', 'output_prefix']

samples_df = cells_df[cols_to_keep]
samples_df
# Out:
#           sample_id  \
# 0        A1_B001800
# 1    A21_1001000366
# 2       A21_B003049
# 3        A2_B001797
# 4        A2_B001798
# 5        A2_B001799
# 6        A2_B003785
# 7        A3_B001798
# 8     A4_1001000362
# 9        A4_B001798
# 10       A4_B003785
# 11    A5_1001000365
# 12       A5_B001798
# 13       A5_B001799
# 14       A5_B001800
# 15    A6_1001000377
# 16      B21_B003049
# 17       B2_B001797
# 18       B2_B001798
# 19       B2_B001799
# 20       B3_B001797
# 21       B3_B001798
# 22       B3_B001799
# 23       B3_B003785
# 24       B4_B001797
# 25    B5_1001000362
# 26       B5_B001797
# 27       B5_B001799
# 28       B5_B003785
# 29    B6_1001000377
# ..              ...
# 198      O3_B001797
# 199      O3_B001800
# 200      O4_B001797
# 201      O4_B001800
# 202      O4_B003785
# 203      O5_B001797
# 204      O5_B001798
# 205      O5_B001799
# 206      O5_B001800
# 207      O5_B003785
# 208   P1_1001000413
# 209      P1_B001797
# 210      P1_B001798
# 211      P1_B001799
# 212      P1_B001800
# 213  P21_1001000366
# 214      P2_B001797
# 215      P2_B001798
# 216      P2_B003785
# 217      P3_B001797
# 218      P3_B001800
# 219      P3_B003785
# 220      P4_B001797
# 221      P4_B001800
# 222      P4_B003785
# 223      P5_B001797
# 224      P5_B001798
# 225      P5_B001799
# 226      P5_B001800
# 227      P5_B003785
#
#                                                                                                               input_fq_1  \
# 0            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3             s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
# 5            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001799/A2_B001799_S194_R1_001.fastq.gz
# 6            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B003785/A2_B003785_S146_R1_001.fastq.gz
# 7            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A3_B001798/A3_B001798_S111_R1_001.fastq.gz
# 8        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_1001000362/A4_1001000362_S4_R1_001.fastq.gz
# 9            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B001798/A4_B001798_S112_R1_001.fastq.gz
# 10           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B003785/A4_B003785_S148_R1_001.fastq.gz
# 11     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_1001000365/A5_1001000365_S173_R1_001.fastq.gz
# 12           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001798/A5_B001798_S113_R1_001.fastq.gz
# 13           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001799/A5_B001799_S197_R1_001.fastq.gz
# 14           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001800/A5_B001800_S281_R1_001.fastq.gz
# 15     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A6_1001000377/A6_1001000377_S126_R1_001.fastq.gz
# 16         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B21_B003049/B21_B003049_S105_R1_001.fastq.gz
# 17            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001797/B2_B001797_S50_R1_001.fastq.gz
# 18           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001798/B2_B001798_S134_R1_001.fastq.gz
# 19           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001799/B2_B001799_S218_R1_001.fastq.gz
# 20            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001797/B3_B001797_S51_R1_001.fastq.gz
# 21           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001798/B3_B001798_S135_R1_001.fastq.gz
# 22           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001799/B3_B001799_S219_R1_001.fastq.gz
# 23           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B003785/B3_B003785_S171_R1_001.fastq.gz
# 24            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B4_B001797/B4_B001797_S52_R1_001.fastq.gz
# 25      s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_1001000362/B5_1001000362_S29_R1_001.fastq.gz
# 26            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001797/B5_B001797_S53_R1_001.fastq.gz
# 27           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001799/B5_B001799_S221_R1_001.fastq.gz
# 28           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B003785/B5_B003785_S173_R1_001.fastq.gz
# 29     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B6_1001000377/B6_1001000377_S150_R1_001.fastq.gz
# ..                                                                                                                   ...
# 198           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O3_B001797/O3_B001797_S63_R1_001.fastq.gz
# 199           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O3_B001800/O3_B001800_S15_R1_001.fastq.gz
# 200           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B001797/O4_B001797_S64_R1_001.fastq.gz
# 201           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B001800/O4_B001800_S16_R1_001.fastq.gz
# 202          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B003785/O4_B003785_S184_R1_001.fastq.gz
# 203           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001797/O5_B001797_S65_R1_001.fastq.gz
# 204          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001798/O5_B001798_S149_R1_001.fastq.gz
# 205          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001799/O5_B001799_S233_R1_001.fastq.gz
# 206           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001800/O5_B001800_S17_R1_001.fastq.gz
# 207          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B003785/O5_B003785_S185_R1_001.fastq.gz
# 208      s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_1001000413/P1_1001000413_S1_R1_001.fastq.gz
# 209           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001797/P1_B001797_S85_R1_001.fastq.gz
# 210          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001798/P1_B001798_S169_R1_001.fastq.gz
# 211          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001799/P1_B001799_S253_R1_001.fastq.gz
# 212           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001800/P1_B001800_S37_R1_001.fastq.gz
# 213  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P21_1001000366/P21_1001000366_S117_R1_001.fastq.gz
# 214           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B001797/P2_B001797_S86_R1_001.fastq.gz
# 215          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B001798/P2_B001798_S170_R1_001.fastq.gz
# 216          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B003785/P2_B003785_S206_R1_001.fastq.gz
# 217           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B001797/P3_B001797_S87_R1_001.fastq.gz
# 218           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B001800/P3_B001800_S39_R1_001.fastq.gz
# 219          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B003785/P3_B003785_S207_R1_001.fastq.gz
# 220           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B001797/P4_B001797_S88_R1_001.fastq.gz
# 221           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B001800/P4_B001800_S40_R1_001.fastq.gz
# 222          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B003785/P4_B003785_S208_R1_001.fastq.gz
# 223           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001797/P5_B001797_S89_R1_001.fastq.gz
# 224          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001798/P5_B001798_S173_R1_001.fastq.gz
# 225          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001799/P5_B001799_S257_R1_001.fastq.gz
# 226           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001800/P5_B001800_S41_R1_001.fastq.gz
# 227          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B003785/P5_B003785_S209_R1_001.fastq.gz
#
#                                                                                                               input_fq_1  \
# 0            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3             s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
# 5            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001799/A2_B001799_S194_R1_001.fastq.gz
# 6            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B003785/A2_B003785_S146_R1_001.fastq.gz
# 7            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A3_B001798/A3_B001798_S111_R1_001.fastq.gz
# 8        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_1001000362/A4_1001000362_S4_R1_001.fastq.gz
# 9            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B001798/A4_B001798_S112_R1_001.fastq.gz
# 10           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B003785/A4_B003785_S148_R1_001.fastq.gz
# 11     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_1001000365/A5_1001000365_S173_R1_001.fastq.gz
# 12           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001798/A5_B001798_S113_R1_001.fastq.gz
# 13           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001799/A5_B001799_S197_R1_001.fastq.gz
# 14           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001800/A5_B001800_S281_R1_001.fastq.gz
# 15     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A6_1001000377/A6_1001000377_S126_R1_001.fastq.gz
# 16         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B21_B003049/B21_B003049_S105_R1_001.fastq.gz
# 17            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001797/B2_B001797_S50_R1_001.fastq.gz
# 18           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001798/B2_B001798_S134_R1_001.fastq.gz
# 19           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001799/B2_B001799_S218_R1_001.fastq.gz
# 20            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001797/B3_B001797_S51_R1_001.fastq.gz
# 21           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001798/B3_B001798_S135_R1_001.fastq.gz
# 22           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001799/B3_B001799_S219_R1_001.fastq.gz
# 23           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B003785/B3_B003785_S171_R1_001.fastq.gz
# 24            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B4_B001797/B4_B001797_S52_R1_001.fastq.gz
# 25      s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_1001000362/B5_1001000362_S29_R1_001.fastq.gz
# 26            s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001797/B5_B001797_S53_R1_001.fastq.gz
# 27           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001799/B5_B001799_S221_R1_001.fastq.gz
# 28           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B003785/B5_B003785_S173_R1_001.fastq.gz
# 29     s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B6_1001000377/B6_1001000377_S150_R1_001.fastq.gz
# ..                                                                                                                   ...
# 198           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O3_B001797/O3_B001797_S63_R1_001.fastq.gz
# 199           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O3_B001800/O3_B001800_S15_R1_001.fastq.gz
# 200           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B001797/O4_B001797_S64_R1_001.fastq.gz
# 201           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B001800/O4_B001800_S16_R1_001.fastq.gz
# 202          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O4_B003785/O4_B003785_S184_R1_001.fastq.gz
# 203           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001797/O5_B001797_S65_R1_001.fastq.gz
# 204          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001798/O5_B001798_S149_R1_001.fastq.gz
# 205          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001799/O5_B001799_S233_R1_001.fastq.gz
# 206           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B001800/O5_B001800_S17_R1_001.fastq.gz
# 207          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/O5_B003785/O5_B003785_S185_R1_001.fastq.gz
# 208      s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_1001000413/P1_1001000413_S1_R1_001.fastq.gz
# 209           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001797/P1_B001797_S85_R1_001.fastq.gz
# 210          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001798/P1_B001798_S169_R1_001.fastq.gz
# 211          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001799/P1_B001799_S253_R1_001.fastq.gz
# 212           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P1_B001800/P1_B001800_S37_R1_001.fastq.gz
# 213  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P21_1001000366/P21_1001000366_S117_R1_001.fastq.gz
# 214           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B001797/P2_B001797_S86_R1_001.fastq.gz
# 215          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B001798/P2_B001798_S170_R1_001.fastq.gz
# 216          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P2_B003785/P2_B003785_S206_R1_001.fastq.gz
# 217           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B001797/P3_B001797_S87_R1_001.fastq.gz
# 218           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B001800/P3_B001800_S39_R1_001.fastq.gz
# 219          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P3_B003785/P3_B003785_S207_R1_001.fastq.gz
# 220           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B001797/P4_B001797_S88_R1_001.fastq.gz
# 221           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B001800/P4_B001800_S40_R1_001.fastq.gz
# 222          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P4_B003785/P4_B003785_S208_R1_001.fastq.gz
# 223           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001797/P5_B001797_S89_R1_001.fastq.gz
# 224          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001798/P5_B001798_S173_R1_001.fastq.gz
# 225          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001799/P5_B001799_S257_R1_001.fastq.gz
# 226           s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B001800/P5_B001800_S41_R1_001.fastq.gz
# 227          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/P5_B003785/P5_B003785_S209_R1_001.fastq.gz
#
#                                                               output_prefix
# 0    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 1    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 2    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 3    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 4    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 5    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 6    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 7    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 8    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 9    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 10   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 11   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 12   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 13   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 14   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 15   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 16   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 17   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 18   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 19   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 20   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 21   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 22   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 23   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 24   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 25   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 26   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 27   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 28   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 29   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# ..                                                                      ...
# 198  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 199  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 200  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 201  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 202  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 203  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 204  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 205  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 206  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 207  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 208  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 209  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 210  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 211  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 212  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 213  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 214  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 215  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 216  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 217  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 218  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 219  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 220  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 221  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 222  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 223  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 224  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 225  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 226  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 227  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
#
# [228 rows x 4 columns]

# %%
# rename cols? 
samples_df.columns = ['sample_id','input_fq1','input_fq2', 'output_dir']
samples_df.head()
# Out:
#         sample_id  \
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798
#
#                                                                                                             input_fq1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                             input_fq2  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                output_dir  \
# 0  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 2  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 3  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 4  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
#
#                id
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798

# %%
# create ID col
#samples_df['id'] = samples_df['sample_id']
samples_df.head()
# Out:
#         sample_id  \
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798
#
#                                                                                                             input_fq1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                             input_fq2  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                output_dir  \
# 0  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 2  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 3  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 4  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
#
#                id
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798

# %%
samples_df = samples_df[['id', 'sample_id', 'input_fq1', 'input_fq2', 'output_dir']]
samples_df.head()
# Out:
#                id       sample_id  \
# 0      A1_B001800      A1_B001800
# 1  A21_1001000366  A21_1001000366
# 2     A21_B003049     A21_B003049
# 3      A2_B001797      A2_B001797
# 4      A2_B001798      A2_B001798
#
#                                                                                                             input_fq1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                             input_fq2  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                output_dir
# 0  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 2  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 3  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# 4  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/

# %%
# write this guy to a file
import json

out_dir = '../tracer/test'

# write samples_df to file
! mkdir -p $out_dir
samples_df.to_csv(f'{out_dir}/samples.csv', index=False)

# write a config file
config =     {
    "program": "../../reflow/tracer_pipeline.rf",
    "runs_file": "samples.csv"
}

with open(f'{out_dir}/config.json', 'w') as f:
    json.dump(config, f)
    
! head -n 3 $out_dir/samples_big.csv $out_dir/config.json
# Out:
# head: ../tracer/test/samples_big.csv: No such file or directory
# ==> ../tracer/test/config.json <==
# {"program": "../../reflow/tracer_pipeline.rf", "runs_file": "samples.csv"}

# %%
## can we make a function or a class to do everything we just did? 
import os
import pandas as pd
pd.options.display.max_colwidth = 500 # module config? 
pd.options.mode.chained_assignment = None  # disable warning message? 

# get_fastqs_R1()
#      get full s3 paths for fastq file (R1), then add them to a new col in cells_df
def get_fastqs_R1(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    try:
        fq_line = [x for x in lines if x.endswith('R1_001.fastq.gz')][0] # get the fastq files, specifically
        fq_basename = fq_line.split()[-1]
        return f'{s3_location}{fq_basename}'
    except IndexError:
        return
    
# get_fastqs_R2()
# get full s3 paths for fastq file (R2), then add them to a new col in cells_df
def get_fastqs_R2(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    try:
        fq_line = [x for x in lines if x.endswith('R2_001.fastq.gz')][0] # get the fastq files, specifically
        fq_basename = fq_line.split()[-1]
        #print(s3_location)
        return f'{s3_location}{fq_basename}'
    except IndexError:
        return

# driver()
#     Gets cell names given a prefix, and sets up dataframe
def driver(prefix): 
     
    # get all of the cells in a given run directory
    txt = 'runX_cells.txt'
    ! aws s3 ls $prefix > $txt

    # read 180226 cell names into a dataframe
    cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])

    # applying function, and assigning output to new col in cells_df
    cells_df['input_fq_1'] = cells_df['cell_name'].map(get_fastqs_R1) 

    # applying function, and assigning output to new col in cells_df
    cells_df['input_fq_2'] = cells_df['cell_name'].map(get_fastqs_R2)
    
    # add a sample_id col
    cells_df['sample_id'] = cells_df.cell_name.str.strip('/') # getting rid of the forward slashes
    
    # building the output vcf string
    cells_df['output_prefix'] = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/'
    
    # subset cells_df by only what we want
    cols_to_keep = ['sample_id', 'input_fq_1', 'input_fq_1', 'output_prefix']
    samples_df = cells_df[cols_to_keep]
    
    # rename cols and add ID col
    samples_df.columns = ['sample_id','input_fq1','input_fq2', 'output_dir']
    samples_df['id'] = samples_df['sample_id']

    # rearrange cols
    samples_df = samples_df[['id', 'sample_id', 'input_fq1', 'input_fq2', 'output_dir']]

# %%
# call this our Main() i guess
#       run driver function

# get all of the run prefixes w/in immuneCells_9.27
bucketPrefixes = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/'
f = 'nonImmune_bams_9.27_prefixes.txt'
! aws s3 ls $bucketPrefixes > $f
    
# read run prefixes into a pandas df
runs_df = pd.read_table(f, delim_whitespace=True, header=None, names=['is_prefix', 'run_name'])
    
# add a full_path col
runs_df['full_path'] = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/' + runs_df['run_name']
    
big_df = pd.DataFrame() # init empty dataframe

for i in range(0, len(runs_df.index)-1):
    global prefix # dont like this
    prefix = runs_df['full_path'][i]
    print(prefix)
    curr_df = driver(prefix)
    toConcat = [big_df, curr_df]
    big_df = pd.concat(toConcat)
    
big_df.head()
# Out:
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170125/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170202/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170215/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170504/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170508/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170510/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/171120/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180307/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180319/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180320/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180405/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180423/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180516/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180519/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180601/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180604/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180711/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180831/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180911/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/trinity_out/
# Empty DataFrame
# Columns: []
# Index: []

# %%
curr_df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-1bc64c7fdf40> in <module>()
# ----> 1 curr_df.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'
